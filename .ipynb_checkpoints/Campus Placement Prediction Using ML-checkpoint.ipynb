# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\faroo\Desktop\major_project\Placement_Data.csv')

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 1. Display Top 5 Rows of The Dataset

# %%
data.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  puc_p  puc_b    puc  degree_p Branch workex  \
# 0      1      M  67.00   Others  91.00  rgukt    mpc     58.00    cse     No
# 1      2      M  79.33  Central  78.33  rgukt  mbipc     77.48    cse    Yes
# 2      3      M  65.00  Central  68.00  rgukt  mbipc     64.00    cse     No
# 3      4      M  56.00  Central  52.00  rgukt  mbipc     52.00    cse     No
# 4      5      M  85.80  Central  73.60  rgukt  mbipc     73.30    cse     No
#
#    etest_p specialisation  gate_p      status    salary
# 0     55.0             ml   58.80      Placed  270000.0
# 1     86.5            web   66.28      Placed  200000.0
# 2     75.0            web   57.80      Placed  250000.0
# 3     66.0             ml   59.43  Not Placed       NaN
# 4     96.8             ml   55.50      Placed  425000.0

# %% [markdown]
# ### 2. Check Last 5 Rows of The Dataset

# %%
data.tail()
# Out:
#      sl_no gender  ssc_p    ssc_b  puc_p  puc_b    puc  degree_p Branch  \
# 210    211      M   80.6   Others   82.0  rgukt    mpc      77.6    cse
# 211    212      M   58.0   Others   60.0  rgukt    mpc      72.0    cse
# 212    213      M   67.0   Others   67.0  rgukt  mbipc      73.0    cse
# 213    214      F   74.0   Others   66.0  rgukt  mbipc      58.0    cse
# 214    215      M   62.0  Central   58.0  rgukt  mbipc      53.0    cse
#
#     workex  etest_p specialisation  gate_p      status    salary
# 210     No     91.0             ml   74.49      Placed  400000.0
# 211     No     74.0            web   53.62      Placed  275000.0
# 212    Yes     59.0             ml   69.72      Placed  295000.0
# 213     No     70.0            web   60.23      Placed  204000.0
# 214     No     89.0            web   60.22  Not Placed       NaN

# %% [markdown]
# ### 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
data.shape
# Out:
# (215, 15)

# %%
print("Number of Rows",data.shape[0])
print("Number of Columns",data.shape[1])
# Out:
# Number of Rows 215
# Number of Columns 15

# %% [markdown]
# ### 4. Get Information About Our Dataset Like the Total Number of Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   puc_p           215 non-null    float64
#  5   puc_b           215 non-null    object
#  6   puc             215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   Branch          215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  gate_p          215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %% [markdown]
# ### 5. Check Null Values In The Dataset

# %%
data.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# puc_p              0
# puc_b              0
# puc                0
# degree_p           0
# Branch             0
# workex             0
# etest_p            0
# specialisation     0
# gate_p             0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# ### 6. Get Overall Statistics About The Dataset

# %%
data.describe()
# Out:
#             sl_no       ssc_p       puc_p    degree_p     etest_p      gate_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %% [markdown]
# ### 7. EDA

# %%
data.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'puc_p', 'puc_b', 'puc',
#        'degree_p', 'Branch', 'workex', 'etest_p', 'specialisation', 'gate_p',
#        'status', 'salary'],
#       dtype='object')

# %% [markdown]
# #### How Many Students Got Placed?

# %%
data['status'].unique()
# Out:
# array(['Placed', 'Not Placed'], dtype=object)

# %%
data['status'].value_counts()
# Out:
# status
# Placed        148
# Not Placed     67
# Name: count, dtype: int64

# %% [markdown]
# #### Could you display the top 5 sci&tech students placed according to their salary?

# %%
data.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'puc_p', 'puc_b', 'puc',
#        'degree_p', 'Branch', 'workex', 'etest_p', 'specialisation', 'gate_p',
#        'status', 'salary'],
#       dtype='object')

# %%
data[(data['Branch']=="cse") & (data['status']=="Placed")].sort_values(by="salary",ascending=False).head()
# Out:
#      sl_no gender  ssc_p    ssc_b  puc_p  puc_b    puc  degree_p Branch  \
# 177    178      F  73.00  Central  97.00  rgukt    mpc     79.00    cse
# 174    175      M  73.24   Others  50.83  rgukt    mpc     64.27    cse
# 163    164      M  63.00   Others  67.00  rgukt    mpc     64.00    cse
# 53      54      M  80.00   Others  70.00  rgukt    mpc     72.00    cse
# 4        5      M  85.80  Central  73.60  rgukt  mbipc     73.30    cse
#
#     workex  etest_p specialisation  gate_p  status    salary
# 177    Yes     89.0            web   70.81  Placed  650000.0
# 174    Yes     64.0             ml   66.23  Placed  500000.0
# 163     No     75.0             ml   66.46  Placed  500000.0
# 53      No     87.0            web   71.04  Placed  450000.0
# 4       No     96.8             ml   55.50  Placed  425000.0

# %% [markdown]
# ### 8. Data Preprocessing

# %%
data.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  puc_p  puc_b    puc  degree_p Branch workex  \
# 0      1      M  67.00   Others  91.00  rgukt    mpc     58.00    cse     No
# 1      2      M  79.33  Central  78.33  rgukt  mbipc     77.48    cse    Yes
# 2      3      M  65.00  Central  68.00  rgukt  mbipc     64.00    cse     No
# 3      4      M  56.00  Central  52.00  rgukt  mbipc     52.00    cse     No
# 4      5      M  85.80  Central  73.60  rgukt  mbipc     73.30    cse     No
#
#    etest_p specialisation  gate_p      status    salary
# 0     55.0             ml   58.80      Placed  270000.0
# 1     86.5            web   66.28      Placed  200000.0
# 2     75.0            web   57.80      Placed  250000.0
# 3     66.0             ml   59.43  Not Placed       NaN
# 4     96.8             ml   55.50      Placed  425000.0

# %%
data = data.drop(['sl_no','salary'],axis=1)

# %%
data.head(1)
# Out:
#   gender  ssc_p   ssc_b  puc_p  puc_b  puc  degree_p Branch workex  etest_p  \
# 0      M   67.0  Others   91.0  rgukt  mpc      58.0    cse     No     55.0
#
#   specialisation  gate_p  status
# 0             ml    58.8  Placed

# %% [markdown]
# #### Encoding the Categorical Columns

# %%
data['ssc_b'].unique()
# Out:
# array(['Others', 'Central'], dtype=object)

# %%
data['ssc_b'] = data['ssc_b'].map({'Central':1,'Others':0})

# %%
data.head(2)
# Out:
#   gender  ssc_p  ssc_b  puc_p  puc_b    puc  degree_p Branch workex  etest_p  \
# 0      M  67.00      0  91.00  rgukt    mpc     58.00    cse     No     55.0
# 1      M  79.33      1  78.33  rgukt  mbipc     77.48    cse    Yes     86.5
#
#   specialisation  gate_p  status
# 0             ml   58.80  Placed
# 1            web   66.28  Placed

# %%
data['puc_b'].unique()
# Out:
# array(['rgukt'], dtype=object)

# %%
data['puc_b'] = data['puc_b'].map({'rgukt':1})

# %%
data.head(2)
# Out:
#   gender  ssc_p  ssc_b  puc_p  puc_b    puc  degree_p Branch workex  etest_p  \
# 0      M  67.00      0  91.00      1    mpc     58.00    cse     No     55.0
# 1      M  79.33      1  78.33      1  mbipc     77.48    cse    Yes     86.5
#
#   specialisation  gate_p  status
# 0             ml   58.80  Placed
# 1            web   66.28  Placed

# %%
data['puc'].unique()
# Out:
# array(['mpc', 'mbipc'], dtype=object)

# %%
data['puc'] = data['puc'].map({'mpc':0,'mbipc':1})

# %%
data.head()
# Out:
#   gender  ssc_p  ssc_b  puc_p  puc_b  puc  degree_p Branch workex  etest_p  \
# 0      M  67.00      0  91.00      1    0     58.00    cse     No     55.0
# 1      M  79.33      1  78.33      1    1     77.48    cse    Yes     86.5
# 2      M  65.00      1  68.00      1    1     64.00    cse     No     75.0
# 3      M  56.00      1  52.00      1    1     52.00    cse     No     66.0
# 4      M  85.80      1  73.60      1    1     73.30    cse     No     96.8
#
#   specialisation  gate_p      status
# 0             ml   58.80      Placed
# 1            web   66.28      Placed
# 2            web   57.80      Placed
# 3             ml   59.43  Not Placed
# 4             ml   55.50      Placed

# %%
data['Branch'].unique()
# Out:
# array(['cse', 'ece', 'eee', 'mech', 'civil', 'chem', 'mme'], dtype=object)

# %%
data['Branch'] = data['Branch'].map({'cse':0,'ece':1,'eee':2,'mech':3,'civil':4,'chem':5,'mme':6})

# %%
data.head(2)
# Out:
#   gender  ssc_p  ssc_b  puc_p  puc_b  puc  degree_p  Branch workex  etest_p  \
# 0      M  67.00      0  91.00      1    0     58.00       0     No     55.0
# 1      M  79.33      1  78.33      1    1     77.48       0    Yes     86.5
#
#   specialisation  gate_p  status
# 0             ml   58.80  Placed
# 1            web   66.28  Placed

# %%
data['specialisation'].unique()
# Out:
# array(['ml', 'web'], dtype=object)

# %%
data['specialisation'] =data['specialisation'].map({'web':1,'ml':0})

# %%
data.head(2)
# Out:
#   gender  ssc_p  ssc_b  puc_p  puc_b  puc  degree_p  Branch workex  etest_p  \
# 0      M  67.00      0  91.00      1    0     58.00       0     No     55.0
# 1      M  79.33      1  78.33      1    1     77.48       0    Yes     86.5
#
#    specialisation  gate_p  status
# 0               0   58.80  Placed
# 1               1   66.28  Placed

# %%
data['workex'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data['workex'] = data['workex'].map({'Yes':1,'No':0})

# %%
data.head(2)
# Out:
#   gender  ssc_p  ssc_b  puc_p  puc_b  puc  degree_p  Branch  workex  etest_p  \
# 0      M  67.00      0  91.00      1    0     58.00       0       0     55.0
# 1      M  79.33      1  78.33      1    1     77.48       0       1     86.5
#
#    specialisation  gate_p  status
# 0               0   58.80  Placed
# 1               1   66.28  Placed

# %%
data['status'].unique()
# Out:
# array(['Placed', 'Not Placed'], dtype=object)

# %%
data['status'] = data['status'].map({'Placed':1,'Not Placed':0})

# %%
data.head()
# Out:
#   gender  ssc_p  ssc_b  puc_p  puc_b  puc  degree_p  Branch  workex  etest_p  \
# 0      M  67.00      0  91.00      1    0     58.00       0       0     55.0
# 1      M  79.33      1  78.33      1    1     77.48       0       1     86.5
# 2      M  65.00      1  68.00      1    1     64.00       0       0     75.0
# 3      M  56.00      1  52.00      1    1     52.00       0       0     66.0
# 4      M  85.80      1  73.60      1    1     73.30       0       0     96.8
#
#    specialisation  gate_p  status
# 0               0   58.80       1
# 1               1   66.28       1
# 2               1   57.80       1
# 3               0   59.43       0
# 4               0   55.50       1

# %%
data['gender'] = data['gender'].map({'M': 1, 'F': 0})

# %%
data.head()
# Out:
#    gender  ssc_p  ssc_b  puc_p  puc_b  puc  degree_p  Branch  workex  etest_p  \
# 0       1  67.00      0  91.00      1    0     58.00       0       0     55.0
# 1       1  79.33      1  78.33      1    1     77.48       0       1     86.5
# 2       1  65.00      1  68.00      1    1     64.00       0       0     75.0
# 3       1  56.00      1  52.00      1    1     52.00       0       0     66.0
# 4       1  85.80      1  73.60      1    1     73.30       0       0     96.8
#
#    specialisation  gate_p  status
# 0               0   58.80       1
# 1               1   66.28       1
# 2               1   57.80       1
# 3               0   59.43       0
# 4               0   55.50       1

# %% [markdown]
# ### 9. Store Feature Matrix In X and Response(Target) In Vector y

# %%
data.columns
# Out:
# Index(['gender', 'ssc_p', 'ssc_b', 'puc_p', 'puc_b', 'puc', 'degree_p',
#        'Branch', 'workex', 'etest_p', 'specialisation', 'gate_p', 'status'],
#       dtype='object')

# %%
X = data.drop('status',axis=1)
y= data['status']

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 210    1
# 211    1
# 212    1
# 213    1
# 214    0
# Name: status, Length: 215, dtype: int64

# %% [markdown]
# ### 10. Splitting The Dataset Into The Training Set And Test Set

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %% [markdown]
# ### 11. Import The models

# %%
    from sklearn.linear_model import LogisticRegression
    from sklearn.neighbors import KNeighborsClassifier
    from sklearn import svm
    from sklearn.tree import DecisionTreeClassifier
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.ensemble import GradientBoostingClassifier

# %% [markdown]
# ### 12. Model Training

# %%
lr = LogisticRegression()
lr.fit(X_train,y_train)

svm = svm.SVC()
svm.fit(X_train,y_train)

knn=KNeighborsClassifier()
knn.fit(X_train,y_train)

dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)

rf=RandomForestClassifier()
rf.fit(X_train,y_train)

gb=GradientBoostingClassifier()
gb.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier()

# %% [markdown]
# ### 13. Prediction on Test Data

# %%
y_pred1 = lr.predict(X_test)
y_pred2 = svm.predict(X_test)
y_pred3 = knn.predict(X_test)
y_pred4 = dt.predict(X_test)
y_pred5 = rf.predict(X_test)
y_pred6 = gb.predict(X_test)

# %% [markdown]
# ### 14. Evaluating the Algorithms

# %%
from sklearn.metrics import accuracy_score

# %%
score1=accuracy_score(y_test,y_pred1)
score2=accuracy_score(y_test,y_pred2)
score3=accuracy_score(y_test,y_pred3)
score4=accuracy_score(y_test,y_pred4)
score5=accuracy_score(y_test,y_pred5)
score6=accuracy_score(y_test,y_pred6)

# %%
print(score1,score2,score3,score4,score5,score6)
# Out:
# 0.8604651162790697 0.7674418604651163 0.7906976744186046 0.7906976744186046 0.7906976744186046 0.7674418604651163

# %%
final_data = pd.DataFrame({'Models':['LR','SVC','KNN','DT','RF','GB'],
            'ACC':[score1*100,
                  score2*100,
                  score3*100,
                  score4*100,
                  score5*100,score6*100]})

# %%
final_data
# Out:
#   Models        ACC
# 0     LR  86.046512
# 1    SVC  76.744186
# 2    KNN  79.069767
# 3     DT  79.069767
# 4     RF  79.069767
# 5     GB  76.744186

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

sns.barplot(x='Models', y='ACC', data=final_data, palette='viridis')
plt.title('Accuracy of Models')
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 15. Prediction on New Data

# %%
new_data = pd.DataFrame({
    'gender':0,
    'ssc_p':67.0,
    'ssc_b':0,
    'puc_p':91.0,
    'puc_b':0,
    'puc':1,
    'degree_p':58.0,
    'Branch':2,
    'workex':0,
    'etest_p':55.0,
     'specialisation':1,
    'gate_p':58.8,   
},index=[0])

# %%
lr= LogisticRegression()
lr.fit(X,y)
# Out:
# LogisticRegression()

# %%
p=lr.predict(new_data)
prob=lr.predict_proba(new_data)
if p==1:
    print('Placed')
    print(f"You will be placed with probability of {prob[0][1]:.2f}")
else:
    print("Not-placed")
# Out:
# Placed
# You will be placed with probability of 1.00

# %%
prob
# Out:
# array([[0.00428224, 0.99571776]])

# %% [markdown]
# ### 16. Save Model Using Joblib

# %%
import joblib

# %%
joblib.dump(lr,'model_campus_placement')
# Out:
# ['model_campus_placement']

# %%
model = joblib.load('model_campus_placement')

# %%
model.predict(new_data)
# Out:
# array([1], dtype=int64)

# %% [markdown]
# ### GUI

# %%
from tkinter import *
import joblib
import numpy as np
from sklearn import *
import tkinter.font as font
import pandas as pd

def show_entry_fields():
    text = clicked.get()
    if text == "Male":
        p1 = 1
    else:
        p1 = 0

    p2 = float(e2.get())
    
    text = clicked1.get()
    if text == "central":
        p3 = 1
    else:
        p3 = 0

    p4 = float(e4.get())

    text = clicked6.get()
    if text == "rgukt":
        p5 = 1
    else:
        p5 = 0

    text = clicked2.get()
    if text == "mpc":
        p6 = 2
    elif text == "mbipc":
        p6 = 1
    else:
        p6 = 0

    p7 = float(e7.get())

    text = clicked3.get()
    branches = {"cse": 6, "ece": 5, "eee": 4, "mech": 3, "chem": 2, "mme": 1, "civil": 0}
    p8 = branches.get(text, 0)

    text = clicked4.get()
    if text == "Yes":
        p9 = 1
    else:
        p9 = 0

    p10 = float(e10.get())

    text = clicked5.get()
    specialisations = {"web": 1, "ml": 0}
    p11 = specialisations.get(text, 0)

    p12 = float(e12.get())

    model = joblib.load('model_campus_placement')
    new_data = pd.DataFrame({
        'gender': p1,
        'ssc_p': p2,
        'ssc_b': p3,
        'puc_p': p4,
        'puc_b': p5,
        'puc': p6,
        'degree_p': p7,
        'Branch': p8,
        'workex': p9,
        'etest_p': p10,
        'specialisation': p11,
        'gate_p': p12,   
    }, index=[0])

    result = model.predict(new_data)
    result1 = model.predict_proba(new_data)

    if result[0] == 0:
        Label(master, text="Can't Be Placed").grid(row=31)
    else:
        Label(master, text="Student Will Be Placed With Probability of", font=("Arial", 15)).grid(row=31)
        Label(master, text=round(result1[0][1], 2) * 100, font=("Arial", 15)).grid(row=33)
        Label(master, text="Percent", font=("Arial", 15)).grid(row=34)

master = Tk()
master.title("Campus Placement Prediction System")

label = Label(master, text="Campus Placement Prediction System", bg="green", fg="white", font=("Arial", 20)).grid(row=0, columnspan=2)

Label(master, text="Gender", font=("Arial", 15)).grid(row=1)
Label(master, text="Secondary Education percentage - 10th Grade", font=("Arial", 15)).grid(row=2)
Label(master, text="Board of Education", font=("Arial", 15)).grid(row=3)
Label(master, text="PUC percentage - 12th Grade", font=("Arial", 15)).grid(row=4)
Label(master, text="Board of Education", font=("Arial", 15)).grid(row=5)
Label(master, text="Specialization in Higher Secondary Education", font=("Arial", 15)).grid(row=6)
Label(master, text="B.Tech Percentage", font=("Arial", 15)).grid(row=7)
Label(master, text="Branch of Engineering ", font=("Arial", 15)).grid(row=8)
Label(master, text="Work Experience", font=("Arial", 15)).grid(row=9)
Label(master, text="Enter test percentage", font=("Arial", 15)).grid(row=10)
Label(master, text="Specialisation", font=("Arial", 15)).grid(row=11)
Label(master, text="Gate percentage", font=("Arial", 15)).grid(row=12)

clicked = StringVar()
options = ["Male", "Female"]

clicked1 = StringVar()
options1 = ["central", "Others"]

clicked2 = StringVar()
options2 = ["mpc", "mbipc", "Others"]

clicked3 = StringVar()
options3 = ["cse", "ece", "eee", "mech", "chem", "mme", "civil"]

clicked4 = StringVar()
options4 = ["Yes", "No"]

clicked5 = StringVar()
options5 = ["web", "ml"]

clicked6 = StringVar()
options6 = ["rgukt", "Others"]

e1 = OptionMenu(master, clicked, *options)
e1.configure(width=13)
e2 = Entry(master)
e3 = OptionMenu(master, clicked1, *options1)
e3.configure(width=13)
e4 = Entry(master)
e5 = OptionMenu(master, clicked6, *options6)
e5.configure(width=13)
e6 = OptionMenu(master, clicked2, *options2)
e6.configure(width=13)
e7 = Entry(master)
e8 = OptionMenu(master, clicked3, *options3)
e8.configure(width=13)
e9 = OptionMenu(master, clicked4, *options4)
e9.configure(width=13)
e10 = Entry(master)
e11 = OptionMenu(master, clicked5, *options5)
e11.configure(width=13)
e12 = Entry(master)

e1.grid(row=1, column=1)
e2.grid(row=2, column=1)
e3.grid(row=3, column=1)
e4.grid(row=4, column=1)
e5.grid(row=5, column=1)
e6.grid(row=6, column=1)
e7.grid(row=7, column=1)
e8.grid(row=8, column=1)
e9.grid(row=9, column=1)
e10.grid(row=10, column=1)
e11.grid(row=11, column=1)
e12.grid(row=12, column=1)

buttonFont = font.Font(family='Helvetica', size=16, weight='bold')
Button(master, text='Predict', height=1, width=8, activebackground='#00ff00', font=buttonFont, bg='black', fg='white', command=show_entry_fields).grid()

mainloop()
